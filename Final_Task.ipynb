# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
data=pd.read_csv("C:/Users/ACER/Desktop/ML_Task 01/DS_ML_FinalTask/DS_ML_FinalTask/student-math.csv",sep=";")
data.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
data["Final_Grade"]=data[["G1","G2","G3"]].sum(axis=1)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 34 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   school       395 non-null    object
#  1   sex          395 non-null    object
#  2   age          395 non-null    int64
#  3   address      395 non-null    object
#  4   famsize      395 non-null    object
#  5   Pstatus      395 non-null    object
#  6   Medu         395 non-null    int64
#  7   Fedu         395 non-null    int64
#  8   Mjob         395 non-null    object
#  9   Fjob         395 non-null    object
#  10  reason       395 non-null    object
#  11  guardian     395 non-null    object
#  12  traveltime   395 non-null    int64
#  13  studytime    395 non-null    int64
#  14  failures     395 non-null    int64
#  15  schoolsup    395 non-null    object
#  16  famsup       395 non-null    object
#  17  paid         395 non-null    object
# ...

# %%
le=LabelEncoder()

# %%
data.iloc[:,[0,1,3,4,5,8,9,10,11,15,16,17,18,19,20,21,22,]]=data.iloc[:,[0,1,3,4,5,8,9,10,11,15,16,17,18,19,20,21,22,]].apply(lambda col:le.fit_transform(col))
data.head()
# Out:
#    school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  ...  \
# 0       0    0   18        1        0        0     4     4     0     4  ...
# 1       0    0   17        1        0        1     1     1     0     2  ...
# 2       0    0   15        1        1        1     1     1     0     2  ...
# 3       0    0   15        1        0        1     4     2     1     3  ...
# 4       0    0   16        1        0        1     3     3     2     2  ...
#
#    freetime  goout  Dalc  Walc  health  absences  G1  G2  G3  Final_Grade
# 0         3      4     1     1       3         6   5   6   6           17
# 1         3      3     1     1       3         4   5   5   6           16
# 2         3      2     2     3       3        10   7   8  10           25
# 3         2      2     1     1       5         2  15  14  15           44
# 4         3      2     1     2       5         4   6  10  10           26
#
# [5 rows x 34 columns]

# %%
real_y=data.iloc[:,33].values
real_x=data.iloc[:,0:32].values

# %%
train_x,test_x,train_y,test_y=train_test_split(real_x,real_y,test_size=0.3,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(train_x,train_y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
regressor.score(test_x,test_y)
# Out:
# 0.9616326234896911

# %%
prediction=regressor.predict(test_x)
from sklearn.metrics import r2_score
r2_score(test_y,prediction)
# Out:
# 0.9616326234896911

# %%
x_opt=real_x
import statsmodels.regression.linear_model as sm
reg_OLs=sm.OLS(endog=real_y,exog=x_opt).fit()

# %%
reg_OLs.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.997
# Model:                            OLS   Adj. R-squared (uncentered):              0.997
# Method:                 Least Squares   F-statistic:                              3979.
# Date:                Sun, 24 May 2020   Prob (F-statistic):                        0.00
# Time:                        03:12:32   Log-Likelihood:                         -794.27
# No. Observations:                 395   AIC:                                      1653.
# Df Residuals:                     363   BIC:                                      1780.
# Df Model:                          32
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
x_opt=np.delete(real_x,3,axis=1)
import statsmodels.regression.linear_model as sm
reg_OLs=sm.OLS(endog=real_y,exog=x_opt).fit()

# %%
reg_OLs.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.997
# Model:                            OLS   Adj. R-squared (uncentered):              0.997
# Method:                 Least Squares   F-statistic:                              4119.
# Date:                Sun, 24 May 2020   Prob (F-statistic):                        0.00
# Time:                        03:24:43   Log-Likelihood:                         -794.28
# No. Observations:                 395   AIC:                                      1651.
# Df Residuals:                     364   BIC:                                      1774.
# Df Model:                          31
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
x_opt=np.delete(real_x,[3,4],axis=1)
import statsmodels.regression.linear_model as sm
reg_OLs=sm.OLS(endog=real_y,exog=x_opt).fit()
reg_OLs.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.997
# Model:                            OLS   Adj. R-squared (uncentered):              0.997
# Method:                 Least Squares   F-statistic:                              4267.
# Date:                Sun, 24 May 2020   Prob (F-statistic):                        0.00
# Time:                        03:35:44   Log-Likelihood:                         -794.29
# No. Observations:                 395   AIC:                                      1649.
# Df Residuals:                     365   BIC:                                      1768.
# Df Model:                          30
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
x_opt=np.delete(x_opt,18,axis=1)
import statsmodels.regression.linear_model as sm
reg_OLs=sm.OLS(endog=real_y,exog=x_opt).fit()
reg_OLs.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.997
# Model:                            OLS   Adj. R-squared (uncentered):              0.997
# Method:                 Least Squares   F-statistic:                              4426.
# Date:                Sun, 24 May 2020   Prob (F-statistic):                        0.00
# Time:                        03:37:20   Log-Likelihood:                         -794.30
# No. Observations:                 395   AIC:                                      1647.
# Df Residuals:                     366   BIC:                                      1762.
# Df Model:                          29
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
x_opt=np.delete(x_opt,6,axis=1)
import statsmodels.regression.linear_model as sm
reg_OLs=sm.OLS(endog=real_y,exog=x_opt).fit()
reg_OLs.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.997
# Model:                            OLS   Adj. R-squared (uncentered):              0.997
# Method:                 Least Squares   F-statistic:                              4596.
# Date:                Sun, 24 May 2020   Prob (F-statistic):                        0.00
# Time:                        03:37:56   Log-Likelihood:                         -794.34
# No. Observations:                 395   AIC:                                      1645.
# Df Residuals:                     367   BIC:                                      1756.
# Df Model:                          28
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
x_opt=np.delete(x_opt,21,axis=1)
import statsmodels.regression.linear_model as sm
reg_OLs=sm.OLS(endog=real_y,exog=x_opt).fit()
reg_OLs.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.997
# Model:                            OLS   Adj. R-squared (uncentered):              0.997
# Method:                 Least Squares   F-statistic:                              4778.
# Date:                Sun, 24 May 2020   Prob (F-statistic):                        0.00
# Time:                        03:38:21   Log-Likelihood:                         -794.38
# No. Observations:                 395   AIC:                                      1643.
# Df Residuals:                     368   BIC:                                      1750.
# Df Model:                          27
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
x_opt=np.delete(x_opt,14,axis=1)
import statsmodels.regression.linear_model as sm
reg_OLs=sm.OLS(endog=real_y,exog=x_opt).fit()
reg_OLs.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.997
# Model:                            OLS   Adj. R-squared (uncentered):              0.997
# Method:                 Least Squares   F-statistic:                              4974.
# Date:                Sun, 24 May 2020   Prob (F-statistic):                        0.00
# Time:                        03:38:37   Log-Likelihood:                         -794.43
# No. Observations:                 395   AIC:                                      1641.
# Df Residuals:                     369   BIC:                                      1744.
# Df Model:                          26
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
x_opt=np.delete(x_opt,8,axis=1)
import statsmodels.regression.linear_model as sm
reg_OLs=sm.OLS(endog=real_y,exog=x_opt).fit()
reg_OLs.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.997
# Model:                            OLS   Adj. R-squared (uncentered):              0.997
# Method:                 Least Squares   F-statistic:                              5184.
# Date:                Sun, 24 May 2020   Prob (F-statistic):                        0.00
# Time:                        03:39:15   Log-Likelihood:                         -794.56
# No. Observations:                 395   AIC:                                      1639.
# Df Residuals:                     370   BIC:                                      1739.
# Df Model:                          25
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
x_opt=np.delete(x_opt,3,axis=1)
import statsmodels.regression.linear_model as sm
reg_OLs=sm.OLS(endog=real_y,exog=x_opt).fit()
reg_OLs.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.997
# Model:                            OLS   Adj. R-squared (uncentered):              0.997
# Method:                 Least Squares   F-statistic:                              5410.
# Date:                Sun, 24 May 2020   Prob (F-statistic):                        0.00
# Time:                        03:39:44   Log-Likelihood:                         -794.73
# No. Observations:                 395   AIC:                                      1637.
# Df Residuals:                     371   BIC:                                      1733.
# Df Model:                          24
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
x_opt=np.delete(x_opt,17,axis=1)
import statsmodels.regression.linear_model as sm
reg_OLs=sm.OLS(endog=real_y,exog=x_opt).fit()
reg_OLs.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.997
# Model:                            OLS   Adj. R-squared (uncentered):              0.997
# Method:                 Least Squares   F-statistic:                              5655.
# Date:                Sun, 24 May 2020   Prob (F-statistic):                        0.00
# Time:                        03:40:06   Log-Likelihood:                         -794.90
# No. Observations:                 395   AIC:                                      1636.
# Df Residuals:                     372   BIC:                                      1727.
# Df Model:                          23
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
x_opt=np.delete(x_opt,7,axis=1)
import statsmodels.regression.linear_model as sm
reg_OLs=sm.OLS(endog=real_y,exog=x_opt).fit()
reg_OLs.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.997
# Model:                            OLS   Adj. R-squared (uncentered):              0.997
# Method:                 Least Squares   F-statistic:                              5923.
# Date:                Sun, 24 May 2020   Prob (F-statistic):                        0.00
# Time:                        03:40:26   Log-Likelihood:                         -795.09
# No. Observations:                 395   AIC:                                      1634.
# Df Residuals:                     373   BIC:                                      1722.
# Df Model:                          22
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
x_opt=np.delete(x_opt,1,axis=1)
import statsmodels.regression.linear_model as sm
reg_OLs=sm.OLS(endog=real_y,exog=x_opt).fit()
reg_OLs.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.997
# Model:                            OLS   Adj. R-squared (uncentered):              0.997
# Method:                 Least Squares   F-statistic:                              6213.
# Date:                Sun, 24 May 2020   Prob (F-statistic):                        0.00
# Time:                        03:40:46   Log-Likelihood:                         -795.36
# No. Observations:                 395   AIC:                                      1633.
# Df Residuals:                     374   BIC:                                      1716.
# Df Model:                          21
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
x_opt=np.delete(x_opt,12,axis=1)
import statsmodels.regression.linear_model as sm
reg_OLs=sm.OLS(endog=real_y,exog=x_opt).fit()
reg_OLs.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.997
# Model:                            OLS   Adj. R-squared (uncentered):              0.997
# Method:                 Least Squares   F-statistic:                              6532.
# Date:                Sun, 24 May 2020   Prob (F-statistic):                        0.00
# Time:                        03:41:07   Log-Likelihood:                         -795.64
# No. Observations:                 395   AIC:                                      1631.
# Df Residuals:                     375   BIC:                                      1711.
# Df Model:                          20
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
x_opt=np.delete(x_opt,5,axis=1)
import statsmodels.regression.linear_model as sm
reg_OLs=sm.OLS(endog=real_y,exog=x_opt).fit()
reg_OLs.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.997
# Model:                            OLS   Adj. R-squared (uncentered):              0.997
# Method:                 Least Squares   F-statistic:                              6882.
# Date:                Sun, 24 May 2020   Prob (F-statistic):                        0.00
# Time:                        03:41:41   Log-Likelihood:                         -795.97
# No. Observations:                 395   AIC:                                      1630.
# Df Residuals:                     376   BIC:                                      1706.
# Df Model:                          19
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
x_opt=np.delete(x_opt,10,axis=1)
import statsmodels.regression.linear_model as sm
reg_OLs=sm.OLS(endog=real_y,exog=x_opt).fit()
reg_OLs.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.997
# Model:                            OLS   Adj. R-squared (uncentered):              0.997
# Method:                 Least Squares   F-statistic:                              7271.
# Date:                Sun, 24 May 2020   Prob (F-statistic):                        0.00
# Time:                        03:42:04   Log-Likelihood:                         -796.30
# No. Observations:                 395   AIC:                                      1629.
# Df Residuals:                     377   BIC:                                      1700.
# Df Model:                          18
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
x_opt=np.delete(x_opt,8,axis=1)
import statsmodels.regression.linear_model as sm
reg_OLs=sm.OLS(endog=real_y,exog=x_opt).fit()
reg_OLs.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.997
# Model:                            OLS   Adj. R-squared (uncentered):              0.997
# Method:                 Least Squares   F-statistic:                              7705.
# Date:                Sun, 24 May 2020   Prob (F-statistic):                        0.00
# Time:                        03:42:27   Log-Likelihood:                         -796.68
# No. Observations:                 395   AIC:                                      1627.
# Df Residuals:                     378   BIC:                                      1695.
# Df Model:                          17
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
x_opt=np.delete(x_opt,11,axis=1)
import statsmodels.regression.linear_model as sm
reg_OLs=sm.OLS(endog=real_y,exog=x_opt).fit()
reg_OLs.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.997
# Model:                            OLS   Adj. R-squared (uncentered):              0.997
# Method:                 Least Squares   F-statistic:                              8187.
# Date:                Sun, 24 May 2020   Prob (F-statistic):                        0.00
# Time:                        03:42:41   Log-Likelihood:                         -797.19
# No. Observations:                 395   AIC:                                      1626.
# Df Residuals:                     379   BIC:                                      1690.
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
x_opt=np.delete(x_opt,12,axis=1)
import statsmodels.regression.linear_model as sm
reg_OLs=sm.OLS(endog=real_y,exog=x_opt).fit()
reg_OLs.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.997
# Model:                            OLS   Adj. R-squared (uncentered):              0.997
# Method:                 Least Squares   F-statistic:                              8733.
# Date:                Sun, 24 May 2020   Prob (F-statistic):                        0.00
# Time:                        03:42:57   Log-Likelihood:                         -797.70
# No. Observations:                 395   AIC:                                      1625.
# Df Residuals:                     380   BIC:                                      1685.
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
x_opt=np.delete(x_opt,5,axis=1)
import statsmodels.regression.linear_model as sm
reg_OLs=sm.OLS(endog=real_y,exog=x_opt).fit()
reg_OLs.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.997
# Model:                            OLS   Adj. R-squared (uncentered):              0.997
# Method:                 Least Squares   F-statistic:                              9355.
# Date:                Sun, 24 May 2020   Prob (F-statistic):                        0.00
# Time:                        03:43:14   Log-Likelihood:                         -798.26
# No. Observations:                 395   AIC:                                      1625.
# Df Residuals:                     381   BIC:                                      1680.
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
x_opt=np.delete(x_opt,4,axis=1)
import statsmodels.regression.linear_model as sm
reg_OLs=sm.OLS(endog=real_y,exog=x_opt).fit()
reg_OLs.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.997
# Model:                            OLS   Adj. R-squared (uncentered):              0.997
# Method:                 Least Squares   F-statistic:                          1.007e+04
# Date:                Sun, 24 May 2020   Prob (F-statistic):                        0.00
# Time:                        03:43:50   Log-Likelihood:                         -798.88
# No. Observations:                 395   AIC:                                      1624.
# Df Residuals:                     382   BIC:                                      1675.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
x_opt=np.delete(x_opt,2,axis=1)
import statsmodels.regression.linear_model as sm
reg_OLs=sm.OLS(endog=real_y,exog=x_opt).fit()
reg_OLs.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.997
# Model:                            OLS   Adj. R-squared (uncentered):              0.997
# Method:                 Least Squares   F-statistic:                          1.090e+04
# Date:                Sun, 24 May 2020   Prob (F-statistic):                        0.00
# Time:                        03:44:14   Log-Likelihood:                         -799.53
# No. Observations:                 395   AIC:                                      1623.
# Df Residuals:                     383   BIC:                                      1671.
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
x_opt=np.delete(x_opt,2,axis=1)
import statsmodels.regression.linear_model as sm
reg_OLs=sm.OLS(endog=real_y,exog=x_opt).fit()
reg_OLs.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.997
# Model:                            OLS   Adj. R-squared (uncentered):              0.997
# Method:                 Least Squares   F-statistic:                          1.191e+04
# Date:                Sun, 24 May 2020   Prob (F-statistic):                        0.00
# Time:                        03:44:40   Log-Likelihood:                         -799.80
# No. Observations:                 395   AIC:                                      1622.
# Df Residuals:                     384   BIC:                                      1665.
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
x_opt=np.delete(x_opt,2,axis=1)
import statsmodels.regression.linear_model as sm
reg_OLs=sm.OLS(endog=real_y,exog=x_opt).fit()
reg_OLs.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.997
# Model:                            OLS   Adj. R-squared (uncentered):              0.997
# Method:                 Least Squares   F-statistic:                          1.308e+04
# Date:                Sun, 24 May 2020   Prob (F-statistic):                        0.00
# Time:                        03:44:57   Log-Likelihood:                         -800.62
# No. Observations:                 395   AIC:                                      1621.
# Df Residuals:                     385   BIC:                                      1661.
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
x_opt=np.delete(x_opt,0,axis=1)
import statsmodels.regression.linear_model as sm
reg_OLs=sm.OLS(endog=real_y,exog=x_opt).fit()
reg_OLs.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.997
# Model:                            OLS   Adj. R-squared (uncentered):              0.997
# Method:                 Least Squares   F-statistic:                          1.448e+04
# Date:                Sun, 24 May 2020   Prob (F-statistic):                        0.00
# Time:                        03:45:13   Log-Likelihood:                         -801.77
# No. Observations:                 395   AIC:                                      1622.
# Df Residuals:                     386   BIC:                                      1657.
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
x_opt=np.delete(x_opt,1,axis=1)
import statsmodels.regression.linear_model as sm
reg_OLs=sm.OLS(endog=real_y,exog=x_opt).fit()
reg_OLs.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.997
# Model:                            OLS   Adj. R-squared (uncentered):              0.997
# Method:                 Least Squares   F-statistic:                          1.628e+04
# Date:                Sun, 24 May 2020   Prob (F-statistic):                        0.00
# Time:                        03:45:32   Log-Likelihood:                         -802.45
# No. Observations:                 395   AIC:                                      1621.
# Df Residuals:                     387   BIC:                                      1653.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
x_opt=np.delete(x_opt,2,axis=1)
import statsmodels.regression.linear_model as sm
reg_OLs=sm.OLS(endog=real_y,exog=x_opt).fit()
reg_OLs.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.997
# Model:                            OLS   Adj. R-squared (uncentered):              0.997
# Method:                 Least Squares   F-statistic:                          1.854e+04
# Date:                Sun, 24 May 2020   Prob (F-statistic):                        0.00
# Time:                        03:45:50   Log-Likelihood:                         -803.69
# No. Observations:                 395   AIC:                                      1621.
# Df Residuals:                     388   BIC:                                      1649.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...
